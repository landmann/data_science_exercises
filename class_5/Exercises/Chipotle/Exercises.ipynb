# %% [markdown]
# # Ex2 - Getting and Knowing your Data

# %%
from IPython.display import Image
Image("images/image.jpg")

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ### Step 2. Find the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv) (No activity required).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo['quantity'].head(n=10)
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    2
# 5    1
# 6    1
# 7    1
# 8    1
# 9    1
# Name: quantity, dtype: int64

# %%
chipo.head(n=10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset? - How many rows are there in the set?

# %%
# Solution 1
print(f'There are {len(chipo)} rows in our dataset')
# Out:
# There are 4622 rows in our dataset

# %%
# Solution 2
chipo.shape
# Out:
# (4622, 5)

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
chipo.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
chipo.count()
# Out:
# order_id              4622
# quantity              4622
# item_name             4622
# choice_description    3376
# item_price            4622
# dtype: int64

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
len(chipo.T)
# Out:
# 5

# %%
len(chipo.columns)
# Out:
# 5

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
print(chipo.columns)
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
for col in enumerate(chipo.columns):
    index, column_name = col
    print(f'{index}. {column_name}')
# Out:
# 0. order_id
# 1. quantity
# 2. item_name
# 3. choice_description
# 4. item_price

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
for index, column_name in enumerate(chipo.columns):
    print(f'{index+1}. {column_name}')
# Out:
# 1. order_id
# 2. quantity
# 3. item_name
# 4. choice_description
# 5. item_price

# %%
[print(f'{index+1}. {column_name}') for index, column_name in enumerate(chipo.columns)];
# Out:
# 1. order_id
# 2. quantity
# 3. item_name
# 4. choice_description
# 5. item_price

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
chipo.mode()
# Out:
#    order_id  quantity     item_name choice_description item_price
# 0       926         1  Chicken Bowl        [Diet Coke]     $8.75

# %%
quantity = chipo['quantity']

# %%
chipo.sort_values(ascending=False, by=['quantity'])
# Out:
#       order_id  quantity                              item_name  \
# 3598      1443        15           Chips and Fresh Tomato Salsa
# 4152      1660        10                          Bottled Water
# 3887      1559         8                          Side of Chips
# 3599      1443         7                          Bottled Water
# 2441       970         5                          Bottled Water
# ...        ...       ...                                    ...
# 1592       645         1                           Chicken Bowl
# 1593       645         1  Chips and Tomatillo Green Chili Salsa
# 1594       646         1                          Carnitas Bowl
# 1595       646         1                        Chicken Burrito
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 3598                                                NaN    $44.25
# ...

# %%
chipo.max()
# Out:
# order_id                   1834
# quantity                     15
# item_name     Veggie Soft Tacos
# item_price               $9.39
# dtype: object

# %%
chipo.groupby(['item_name']).sum('quantity').sort_values(by=['quantity'], ascending=False)
# Out:
#                                        order_id  quantity
# item_name
# Chicken Bowl                             713926       761
# Chicken Burrito                          497303       591
# Chips and Guacamole                      449959       506
# Steak Burrito                            328437       386
# Canned Soft Drink                        304753       351
# Chips                                    208004       230
# Steak Bowl                               193752       221
# Bottled Water                            175944       211
# Chips and Fresh Tomato Salsa             100419       130
# Canned Soda                               76396       126
# Chicken Salad Bowl                       117104       123
# Chicken Soft Tacos                        98395       120
# Side of Chips                             84769       110
# Veggie Burrito                            80962        97
# Barbacoa Burrito                          74718        91
# ...

# %%
# groupby
(chipo.groupby(['item_name'])
      .sum('quantity')
      .sort_values(by=['quantity'], ascending=False)
       ['quantity']
      .plot(kind='bar', figsize=(18, 3)));

# %%
most_ordered = chipo.groupby(['item_name'])['quantity'].sum().sort_values(ascending=False).head(1)

# %%
most_ordered.index[0]
# Out:
# 'Chicken Bowl'

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
most_ordered.values
# Out:
# array([761])

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
# .apply()
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# group by choice 
chipo['choice_description'].apply(type)
# Out:
# 0       <class 'float'>
# 1         <class 'str'>
# 2         <class 'str'>
# 3       <class 'float'>
# 4         <class 'str'>
#              ...
# 4617      <class 'str'>
# 4618      <class 'str'>
# 4619      <class 'str'>
# 4620      <class 'str'>
# 4621      <class 'str'>
# Name: choice_description, Length: 4622, dtype: object

# %%
chipo['choice_description'] = chipo['choice_description'].astype(str)

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                nan     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                nan     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
chipo['choice_description'].str.split(',',expand=True)
# Out:
#                                      0                    1             2  \
# 0                                  nan                 None          None
# 1                         [Clementine]                 None          None
# 2                              [Apple]                 None          None
# 3                                  nan                 None          None
# 4     [Tomatillo-Red Chili Salsa (Hot)         [Black Beans          Rice
# ...                                ...                  ...           ...
# 4617               [Fresh Tomato Salsa                [Rice   Black Beans
# 4618               [Fresh Tomato Salsa                [Rice    Sour Cream
# 4619               [Fresh Tomato Salsa   [Fajita Vegetables   Pinto Beans
# 4620               [Fresh Tomato Salsa   [Fajita Vegetables     Lettuce]]
# 4621               [Fresh Tomato Salsa   [Fajita Vegetables   Pinto Beans
#
#                 3              4             5             6     7     8     9
# ...

# %%
for i, col in chipo.iterrows():
    quantity = col['quantity']
    print(quantity, col['choice_description'])
    if i+1 % 5 == 0: break
# Out:
# 1 nan
# 1 [Clementine]
# 1 [Apple]
# 1 nan
# 2 [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# 1 [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]
# 1 nan
# 1 [Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce]]
# 1 [Tomatillo Green Chili Salsa, [Pinto Beans, Cheese, Sour Cream, Lettuce]]
# 1 [Fresh Tomato Salsa, [Rice, Black Beans, Pinto Beans, Cheese, Sour Cream, Lettuce]]
# 1 nan
# 1 [Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream]]
# 1 [Roasted Chili Corn Salsa, [Rice, Black Beans, Cheese, Sour Cream]]
# 1 [Fresh Tomato Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Guacamole]]
# 1 nan
# 1 nan
# 1 [Tomatillo-Green Chili Salsa (Medium), [Pinto Beans, Cheese, Sour Cream]]
# 1 [Fresh Tomato Salsa (Mild), [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]
# 2 [Sprite]
# ...

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
chipo['quantity'].sum()
# Out:
# 4972

# %%
chipo.quantity.sum()
# Out:
# 4972

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
type(chipo['item_price'].iloc[0])
# Out:
# str

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %%
chipo['item_price'].head()
# Out:
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98
# Name: item_price, dtype: object

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:]))

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
type(chipo['item_price'].iloc[0])
# Out:
# numpy.float64

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
chipo.item_price.sum()
# Out:
# 34500.16

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %%
len(chipo.order_id.unique())
# Out:
# 1834

# %%
chipo.order_id.drop_duplicates().count()
# Out:
# 1834

# %%
chipo.order_id.max()
# Out:
# 1834

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
chipo.head(4)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
#
#   choice_description  item_price
# 0                nan        2.39
# 1       [Clementine]        3.39
# 2            [Apple]        3.39
# 3                nan        2.39

# %%
# Solution 1
chipo.groupby(['order_id'])['item_price'].sum().mean()
# Out:
# 18.811428571428568

# %%
# Solution 2
chipo.item_price.sum() / chipo.order_id.max()
# Out:
# 18.811428571428575

# %% [markdown]
# ### Step 17. How many different items are sold?

# %%
len(chipo.item_name.unique())
# Out:
# 50

# %%
chipo['item_name'].value_counts().sort_index()
# Out:
# 6 Pack Soft Drink                         54
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     11
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            162
# Bowl                                       2
# Burrito                                    6
# Canned Soda                              104
# Canned Soft Drink                        301
# Carnitas Bowl                             68
# Carnitas Burrito                          59
# Carnitas Crispy Tacos                      7
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chicken Crispy Tacos                      47
# Chicken Salad                              9
# ...
